# %%
import pandas as pd

# %%
car_name = pd.Series(["corolla", "toyota", "ferari", "BMW"])

car_name
# Out:
# 0    corolla
# 1     toyota
# 2     ferari
# 3        BMW
# dtype: object

# %%
colors = pd.Series(["Red", "Blue", "green", "Black"])

colors
# Out:
# 0      Red
# 1     Blue
# 2    green
# 3    Black
# dtype: object

# %% [markdown]
# #Different between series and DataFrame is that  Series is 1-D and DataFrame is 2-D

# %%
Car_Data = pd.DataFrame({"Cars": car_name, "Colours": colors})

Car_Data
# Out:
#       Cars Colours
# 0  corolla     Red
# 1   toyota    Blue
# 2   ferari   green
# 3      BMW   Black

# %%
Social_Discussion = pd.read_csv("Social.csv")

Social_Discussion
# Out:
#          SBU  DEPARTMENT      SUB DEPT.  SR #     EMP ID     EMPLOYEE NAME  \
# 0     C.M.T.    ACCOUNTS  GENERAL STAFF     1  111010005    MOHAMMAD ZAHID
# 1     C.M.T.    ACCOUNTS  GENERAL STAFF     2  222160527  AQEEL ANWAR KHAN
# 2     C.M.T.    ACCOUNTS  GENERAL STAFF     3  222161077    WASIF SADDIQUE
# 3     C.M.T.    ACCOUNTS  GENERAL STAFF     4  661040006        ARSHID ALI
# 4     C.M.T.       ADMIN  GENERAL STAFF     5  200501023      SAKHAWAT ALI
# ...      ...         ...            ...   ...        ...               ...
# 1724  TRENDZ  WARE HOUSE       SHIPPING  1725  200502277    MUHAMMAD SAKHI
# 1725  TRENDZ  WARE HOUSE       SHIPPING  1726  200502287   MUHAMMAD FAISAL
# 1726  TRENDZ  WARE HOUSE       SHIPPING  1727  200600079      NAVEED AHMED
# 1727     NaN         NaN            NaN   NaN        NaN               NaN
# 1728     NaN         NaN            NaN   NaN        NaN               NaN
#
#        EMP TYPE      SALARY   DAY WORK    EARND AMT   S.SEC AMT
# ...

# %%
# Sorting out from data
My_Data = Social_Discussion[2: 44]

# %%
#checking the sorted data
My_Data
# Out:
#        SBU      DEPARTMENT      SUB DEPT. SR #     EMP ID  \
# 2   C.M.T.        ACCOUNTS  GENERAL STAFF    3  222161077
# 3   C.M.T.        ACCOUNTS  GENERAL STAFF    4  661040006
# 4   C.M.T.           ADMIN  GENERAL STAFF    5  200501023
# 5   C.M.T.           ADMIN  GENERAL STAFF    6  222160242
# 6   C.M.T.           ADMIN  GENERAL STAFF    7  222160309
# 7   C.M.T.           ADMIN  GENERAL STAFF    8  222161128
# 8   C.M.T.           ADMIN  GENERAL STAFF    9  222161197
# 9   C.M.T.           ADMIN        SWEEPER   10  111070041
# 10  C.M.T.           ADMIN        SWEEPER   11  222161107
# 11  C.M.T.  C.M.T. CUTTING       CHECKING   12  200502098
# 12  C.M.T.  C.M.T. CUTTING       CHECKING   13  200600069
# 13  C.M.T.  C.M.T. CUTTING       CHECKING   14  200600333
# 14  C.M.T.  C.M.T. CUTTING       CHECKING   15  200600399
# 15  C.M.T.  C.M.T. CUTTING       CHECKING   16  200600662
# 16  C.M.T.  C.M.T. CUTTING       CHECKING   17  200600704
# ...

# %%
My_Data
# Out:
#        SBU      DEPARTMENT      SUB DEPT. SR #     EMP ID  \
# 2   C.M.T.        ACCOUNTS  GENERAL STAFF    3  222161077
# 3   C.M.T.        ACCOUNTS  GENERAL STAFF    4  661040006
# 4   C.M.T.           ADMIN  GENERAL STAFF    5  200501023
# 5   C.M.T.           ADMIN  GENERAL STAFF    6  222160242
# 6   C.M.T.           ADMIN  GENERAL STAFF    7  222160309
# 7   C.M.T.           ADMIN  GENERAL STAFF    8  222161128
# 8   C.M.T.           ADMIN  GENERAL STAFF    9  222161197
# 9   C.M.T.           ADMIN        SWEEPER   10  111070041
# 10  C.M.T.           ADMIN        SWEEPER   11  222161107
# 11  C.M.T.  C.M.T. CUTTING       CHECKING   12  200502098
# 12  C.M.T.  C.M.T. CUTTING       CHECKING   13  200600069
# 13  C.M.T.  C.M.T. CUTTING       CHECKING   14  200600333
# 14  C.M.T.  C.M.T. CUTTING       CHECKING   15  200600399
# 15  C.M.T.  C.M.T. CUTTING       CHECKING   16  200600662
# 16  C.M.T.  C.M.T. CUTTING       CHECKING   17  200600704
# ...

# %%
# export this dataframe as scv format
My_Data.to_csv('history.csv', index=False)

# %%
history = pd.read_csv('history.csv')

# %%
history.index
# Out:
# RangeIndex(start=0, stop=42, step=1)

# %%
history
# Out:
#        SBU      DEPARTMENT      SUB DEPT.  SR #     EMP ID  \
# 0   C.M.T.        ACCOUNTS  GENERAL STAFF     3  222161077
# 1   C.M.T.        ACCOUNTS  GENERAL STAFF     4  661040006
# 2   C.M.T.           ADMIN  GENERAL STAFF     5  200501023
# 3   C.M.T.           ADMIN  GENERAL STAFF     6  222160242
# 4   C.M.T.           ADMIN  GENERAL STAFF     7  222160309
# 5   C.M.T.           ADMIN  GENERAL STAFF     8  222161128
# 6   C.M.T.           ADMIN  GENERAL STAFF     9  222161197
# 7   C.M.T.           ADMIN        SWEEPER    10  111070041
# 8   C.M.T.           ADMIN        SWEEPER    11  222161107
# 9   C.M.T.  C.M.T. CUTTING       CHECKING    12  200502098
# 10  C.M.T.  C.M.T. CUTTING       CHECKING    13  200600069
# 11  C.M.T.  C.M.T. CUTTING       CHECKING    14  200600333
# 12  C.M.T.  C.M.T. CUTTING       CHECKING    15  200600399
# 13  C.M.T.  C.M.T. CUTTING       CHECKING    16  200600662
# 14  C.M.T.  C.M.T. CUTTING       CHECKING    17  200600704
# ...

# %% [markdown]
# # Attributes on DataFram

# %% [markdown]
# Attributes have no brackets at the end, and it returns the store values don't perform any steps to

# %%
history.index[4]
# Out:
# 4

# %%
history.index[34]
# Out:
# 34

# %%
history.dtypes
# Out:
# SBU              object
# DEPARTMENT       object
# SUB DEPT.        object
# SR #              int64
# EMP ID            int64
# EMPLOYEE NAME    object
# EMP TYPE         object
#  SALARY          object
#  DAY WORK         int64
#  EARND AMT       object
#  S.SEC AMT        int64
# dtype: object

# %%
history.columns
# Out:
# Index(['SBU', 'DEPARTMENT', 'SUB DEPT.', 'SR #', 'EMP ID', 'EMPLOYEE NAME',
#        'EMP TYPE', ' SALARY ', ' DAY WORK ', ' EARND AMT ', ' S.SEC AMT '],
#       dtype='object')

# %%
history_columns = history.columns

# %%
history_columns
# Out:
# Index(['SBU', 'DEPARTMENT', 'SUB DEPT.', 'SR #', 'EMP ID', 'EMPLOYEE NAME',
#        'EMP TYPE', ' SALARY ', ' DAY WORK ', ' EARND AMT ', ' S.SEC AMT '],
#       dtype='object')

# %% [markdown]
# # Functions on DataFrame

# %%
history
# Out:
#        SBU      DEPARTMENT      SUB DEPT.  SR #     EMP ID  \
# 0   C.M.T.        ACCOUNTS  GENERAL STAFF     3  222161077
# 1   C.M.T.        ACCOUNTS  GENERAL STAFF     4  661040006
# 2   C.M.T.           ADMIN  GENERAL STAFF     5  200501023
# 3   C.M.T.           ADMIN  GENERAL STAFF     6  222160242
# 4   C.M.T.           ADMIN  GENERAL STAFF     7  222160309
# 5   C.M.T.           ADMIN  GENERAL STAFF     8  222161128
# 6   C.M.T.           ADMIN  GENERAL STAFF     9  222161197
# 7   C.M.T.           ADMIN        SWEEPER    10  111070041
# 8   C.M.T.           ADMIN        SWEEPER    11  222161107
# 9   C.M.T.  C.M.T. CUTTING       CHECKING    12  200502098
# 10  C.M.T.  C.M.T. CUTTING       CHECKING    13  200600069
# 11  C.M.T.  C.M.T. CUTTING       CHECKING    14  200600333
# 12  C.M.T.  C.M.T. CUTTING       CHECKING    15  200600399
# 13  C.M.T.  C.M.T. CUTTING       CHECKING    16  200600662
# 14  C.M.T.  C.M.T. CUTTING       CHECKING    17  200600704
# ...

# %%
history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SBU            42 non-null     object
#  1   DEPARTMENT     42 non-null     object
#  2   SUB DEPT.      42 non-null     object
#  3   SR #           42 non-null     int64
#  4   EMP ID         42 non-null     int64
#  5   EMPLOYEE NAME  42 non-null     object
#  6   EMP TYPE       42 non-null     object
#  7    SALARY        42 non-null     object
#  8    DAY WORK      42 non-null     int64
#  9    EARND AMT     42 non-null     object
#  10   S.SEC AMT     42 non-null     int64
# dtypes: int64(4), object(7)
# memory usage: 3.7+ KB

# %%
history.describe()
# Out:
#             SR #        EMP ID   DAY WORK    S.SEC AMT
# count  42.000000  4.200000e+01   42.000000    42.000000
# mean   23.500000  2.196685e+08   30.095238   284.095238
# std    12.267844  7.225355e+07    1.845357    48.480728
# min     3.000000  1.110700e+08   23.000000   190.000000
# 25%    13.250000  2.005020e+08   30.000000   257.000000
# 50%    23.500000  2.113455e+08   31.000000   266.000000
# 75%    33.750000  2.221610e+08   31.000000   339.750000
# max    44.000000  6.610400e+08   31.000000   350.000000

# %%
history.sum()
# Out:
# SBU              C.M.T.C.M.T.C.M.T.C.M.T.C.M.T.C.M.T.C.M.T.C.M....
# DEPARTMENT       ACCOUNTSACCOUNTSADMINADMINADMINADMINADMINADMIN...
# SUB DEPT.        GENERAL STAFFGENERAL STAFFGENERAL STAFFGENERAL...
# SR #                                                           987
# EMP ID                                                  9226075922
# EMPLOYEE NAME    WASIF SADDIQUEARSHID ALISAKHAWAT ALIKHALID MAS...
# EMP TYPE         PermanentPermanentPermanentPermanentPermanentP...
#  SALARY           4,600  7,500  4,200  4,716  7,361  3,500  4,2...
#  DAY WORK                                                     1264
#  EARND AMT        4,600  7,500  4,064  4,715  7,361  3,500  4,2...
#  S.SEC AMT                                                   11932
# dtype: object

# %%
history["SR #"].sum()
# Out:
# 987

# %%
history["SR #"]
# Out:
# 0      3
# 1      4
# 2      5
# 3      6
# 4      7
# 5      8
# 6      9
# 7     10
# 8     11
# 9     12
# 10    13
# 11    14
# 12    15
# 13    16
# 14    17
# 15    18
# 16    19
# 17    20
# 18    21
# 19    22
# 20    23
# 21    24
# 22    25
# 23    26
# 24    27
# 25    28
# 26    29
# 27    30
# 28    31
# 29    32
# 30    33
# 31    34
# 32    35
# 33    36
# 34    37
# 35    38
# 36    39
# 37    40
# 38    41
# 39    42
# 40    43
# 41    44
# Name: SR #, dtype: int64

# %%
history.mean()
# Out:
# SR #           2.350000e+01
# EMP ID         2.196685e+08
#  DAY WORK      3.009524e+01
#  S.SEC AMT     2.840952e+02
# dtype: float64

# %%
history.median()
# Out:
# SR #                  23.5
# EMP ID         211345516.5
#  DAY WORK             31.0
#  S.SEC AMT           266.0
# dtype: float64

# %%
type(history)
# Out:
# pandas.core.frame.DataFrame

# %%
history_columns
# Out:
# Index(['SBU', 'DEPARTMENT', 'SUB DEPT.', 'SR #', 'EMP ID', 'EMPLOYEE NAME',
#        'EMP TYPE', ' SALARY ', ' DAY WORK ', ' EARND AMT ', ' S.SEC AMT '],
#       dtype='object')

# %% [markdown]
# # Viewing Data in DataFrame

# %% [markdown]
# history.head()

# %%
history.head()

#return the first 5 items from our DataFram
# Out:
#       SBU DEPARTMENT      SUB DEPT.  SR #     EMP ID   EMPLOYEE NAME  \
# 0  C.M.T.   ACCOUNTS  GENERAL STAFF     3  222161077  WASIF SADDIQUE
# 1  C.M.T.   ACCOUNTS  GENERAL STAFF     4  661040006      ARSHID ALI
# 2  C.M.T.      ADMIN  GENERAL STAFF     5  200501023    SAKHAWAT ALI
# 3  C.M.T.      ADMIN  GENERAL STAFF     6  222160242   KHALID MASIH.
# 4  C.M.T.      ADMIN  GENERAL STAFF     7  222160309     AKHTAR ALI.
#
#     EMP TYPE  SALARY    DAY WORK   EARND AMT    S.SEC AMT
# 0  Permanent   4,600           31      4,600           322
# 1  Permanent   7,500           31      7,500           350
# 2  Permanent   4,200           30      4,064           284
# 3  Permanent   4,716           31      4,715           330
# 4  Permanent   7,361           31      7,361           350

# %%
history.head(8)
# Out:
#       SBU DEPARTMENT      SUB DEPT.  SR #     EMP ID    EMPLOYEE NAME  \
# 0  C.M.T.   ACCOUNTS  GENERAL STAFF     3  222161077   WASIF SADDIQUE
# 1  C.M.T.   ACCOUNTS  GENERAL STAFF     4  661040006       ARSHID ALI
# 2  C.M.T.      ADMIN  GENERAL STAFF     5  200501023     SAKHAWAT ALI
# 3  C.M.T.      ADMIN  GENERAL STAFF     6  222160242    KHALID MASIH.
# 4  C.M.T.      ADMIN  GENERAL STAFF     7  222160309      AKHTAR ALI.
# 5  C.M.T.      ADMIN  GENERAL STAFF     8  222161128    PERVAIZ MASIH
# 6  C.M.T.      ADMIN  GENERAL STAFF     9  222161197    RASHEED AHMAD
# 7  C.M.T.      ADMIN        SWEEPER    10  111070041  MUHAMMAD YOUSAF
#
#     EMP TYPE  SALARY    DAY WORK   EARND AMT    S.SEC AMT
# 0  Permanent   4,600           31      4,600           322
# 1  Permanent   7,500           31      7,500           350
# 2  Permanent   4,200           30      4,064           284
# 3  Permanent   4,716           31      4,715           330
# ...

# %%
# tail function return the last 5 items from our DataFrame
history.tail()
# Out:
#        SBU DEPARTMENT SUB DEPT.  SR #     EMP ID     EMPLOYEE NAME   EMP TYPE  \
# 37  C.M.T.  CLASSIC 1  CHECKING    40  200501073   SAIF ULLAH KHAN  Permanent
# 38  C.M.T.  CLASSIC 1  CHECKING    41  200501100  MUHAMMAD HUSSAIN  Permanent
# 39  C.M.T.  CLASSIC 1  CHECKING    42  200501106   MULAZIM HUSSAIN  Permanent
# 40  C.M.T.  CLASSIC 1  CHECKING    43  200501146          ALI ABID  Permanent
# 41  C.M.T.  CLASSIC 1  CHECKING    44  200501302     AHMAD HUSSAIN  Permanent
#
#     SALARY    DAY WORK   EARND AMT    S.SEC AMT
# 37   3,800           31      3,799           266
# 38   3,800           30      3,677           257
# 39   3,800           31      3,738           262
# 40   3,800           31      3,799           266
# 41   3,800           30      3,677           257

# %%
# let's play with loc and iloc by saving this tail to another variable

new = history.tail(7)

new
# Out:
#        SBU DEPARTMENT SUB DEPT.  SR #     EMP ID     EMPLOYEE NAME   EMP TYPE  \
# 35  C.M.T.  CLASSIC 1  CHECKING    38  200500671    MAJID ALI RAMA  Permanent
# 36  C.M.T.  CLASSIC 1  CHECKING    39  200500672      SAJJAD AHMAD  Permanent
# 37  C.M.T.  CLASSIC 1  CHECKING    40  200501073   SAIF ULLAH KHAN  Permanent
# 38  C.M.T.  CLASSIC 1  CHECKING    41  200501100  MUHAMMAD HUSSAIN  Permanent
# 39  C.M.T.  CLASSIC 1  CHECKING    42  200501106   MULAZIM HUSSAIN  Permanent
# 40  C.M.T.  CLASSIC 1  CHECKING    43  200501146          ALI ABID  Permanent
# 41  C.M.T.  CLASSIC 1  CHECKING    44  200501302     AHMAD HUSSAIN  Permanent
#
#     SALARY    DAY WORK   EARND AMT    S.SEC AMT
# 35   3,800           31      3,799           266
# 36   3,800           31      3,799           266
# 37   3,800           31      3,799           266
# 38   3,800           30      3,677           257
# 39   3,800           31      3,738           262
# ...

# %%
len(new)
# Out:
# 7

# %%
new.loc[4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     349             try:
# --> 350                 return self._range.index(new_key)
#     351             except ValueError:
#
# ValueError: 4 is not in range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f51482f5f834> in <module>
# ----> 1 new.loc[4]
#
# E:\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ...

# %%
history
# Out:
#        SBU      DEPARTMENT      SUB DEPT.  SR #     EMP ID  \
# 0   C.M.T.        ACCOUNTS  GENERAL STAFF     3  222161077
# 1   C.M.T.        ACCOUNTS  GENERAL STAFF     4  661040006
# 2   C.M.T.           ADMIN  GENERAL STAFF     5  200501023
# 3   C.M.T.           ADMIN  GENERAL STAFF     6  222160242
# 4   C.M.T.           ADMIN  GENERAL STAFF     7  222160309
# 5   C.M.T.           ADMIN  GENERAL STAFF     8  222161128
# 6   C.M.T.           ADMIN  GENERAL STAFF     9  222161197
# 7   C.M.T.           ADMIN        SWEEPER    10  111070041
# 8   C.M.T.           ADMIN        SWEEPER    11  222161107
# 9   C.M.T.  C.M.T. CUTTING       CHECKING    12  200502098
# 10  C.M.T.  C.M.T. CUTTING       CHECKING    13  200600069
# 11  C.M.T.  C.M.T. CUTTING       CHECKING    14  200600333
# 12  C.M.T.  C.M.T. CUTTING       CHECKING    15  200600399
# 13  C.M.T.  C.M.T. CUTTING       CHECKING    16  200600662
# 14  C.M.T.  C.M.T. CUTTING       CHECKING    17  200600704
# ...

# %%
history.loc[3]
# Out:
# SBU                     C.M.T.
# DEPARTMENT               ADMIN
# SUB DEPT.        GENERAL STAFF
# SR #                         6
# EMP ID               222160242
# EMPLOYEE NAME    KHALID MASIH.
# EMP TYPE             Permanent
#  SALARY                 4,716
#  DAY WORK                   31
#  EARND AMT              4,715
#  S.SEC AMT                 330
# Name: 3, dtype: object

# %%
history.iloc[3]
# Out:
# SBU                     C.M.T.
# DEPARTMENT               ADMIN
# SUB DEPT.        GENERAL STAFF
# SR #                         6
# EMP ID               222160242
# EMPLOYEE NAME    KHALID MASIH.
# EMP TYPE             Permanent
#  SALARY                 4,716
#  DAY WORK                   31
#  EARND AMT              4,715
#  S.SEC AMT                 330
# Name: 3, dtype: object

# %%
history["DEPARTMENT"]
# Out:
# 0           ACCOUNTS
# 1           ACCOUNTS
# 2              ADMIN
# 3              ADMIN
# 4              ADMIN
# 5              ADMIN
# 6              ADMIN
# 7              ADMIN
# 8              ADMIN
# 9     C.M.T. CUTTING
# 10    C.M.T. CUTTING
# 11    C.M.T. CUTTING
# 12    C.M.T. CUTTING
# 13    C.M.T. CUTTING
# 14    C.M.T. CUTTING
# 15    C.M.T. CUTTING
# 16    C.M.T. CUTTING
# 17    C.M.T. CUTTING
# 18    C.M.T. CUTTING
# 19    C.M.T. CUTTING
# 20    C.M.T. CUTTING
# 21    C.M.T. CUTTING
# 22    C.M.T. CUTTING
# 23    C.M.T. CUTTING
# 24    C.M.T. CUTTING
# 25    C.M.T. CUTTING
# 26    C.M.T. CUTTING
# 27    C.M.T. CUTTING
# 28    C.M.T. CUTTING
# 29    C.M.T. CUTTING
# 30    C.M.T. CUTTING
# 31           CLASSIC
# 32           CLASSIC
# 33           CLASSIC
# 34         CLASSIC 1
# 35         CLASSIC 1
# 36         CLASSIC 1
# 37         CLASSIC 1
# 38         CLASSIC 1
# 39         CLASSIC 1
# 40         CLASSIC 1
# 41         CLASSIC 1
# Name: DEPARTMENT, dtype: object

# %%
history.DEPARTMENT
# Out:
# 0           ACCOUNTS
# 1           ACCOUNTS
# 2              ADMIN
# 3              ADMIN
# 4              ADMIN
# 5              ADMIN
# 6              ADMIN
# 7              ADMIN
# 8              ADMIN
# 9     C.M.T. CUTTING
# 10    C.M.T. CUTTING
# 11    C.M.T. CUTTING
# 12    C.M.T. CUTTING
# 13    C.M.T. CUTTING
# 14    C.M.T. CUTTING
# 15    C.M.T. CUTTING
# 16    C.M.T. CUTTING
# 17    C.M.T. CUTTING
# 18    C.M.T. CUTTING
# 19    C.M.T. CUTTING
# 20    C.M.T. CUTTING
# 21    C.M.T. CUTTING
# 22    C.M.T. CUTTING
# 23    C.M.T. CUTTING
# 24    C.M.T. CUTTING
# 25    C.M.T. CUTTING
# 26    C.M.T. CUTTING
# 27    C.M.T. CUTTING
# 28    C.M.T. CUTTING
# 29    C.M.T. CUTTING
# 30    C.M.T. CUTTING
# 31           CLASSIC
# 32           CLASSIC
# 33           CLASSIC
# 34         CLASSIC 1
# 35         CLASSIC 1
# 36         CLASSIC 1
# 37         CLASSIC 1
# 38         CLASSIC 1
# 39         CLASSIC 1
# 40         CLASSIC 1
# 41         CLASSIC 1
# Name: DEPARTMENT, dtype: object

# %%
new
# Out:
#        SBU DEPARTMENT SUB DEPT.  SR #     EMP ID     EMPLOYEE NAME   EMP TYPE  \
# 35  C.M.T.  CLASSIC 1  CHECKING    38  200500671    MAJID ALI RAMA  Permanent
# 36  C.M.T.  CLASSIC 1  CHECKING    39  200500672      SAJJAD AHMAD  Permanent
# 37  C.M.T.  CLASSIC 1  CHECKING    40  200501073   SAIF ULLAH KHAN  Permanent
# 38  C.M.T.  CLASSIC 1  CHECKING    41  200501100  MUHAMMAD HUSSAIN  Permanent
# 39  C.M.T.  CLASSIC 1  CHECKING    42  200501106   MULAZIM HUSSAIN  Permanent
# 40  C.M.T.  CLASSIC 1  CHECKING    43  200501146          ALI ABID  Permanent
# 41  C.M.T.  CLASSIC 1  CHECKING    44  200501302     AHMAD HUSSAIN  Permanent
#
#     SALARY    DAY WORK   EARND AMT    S.SEC AMT
# 35   3,800           31      3,799           266
# 36   3,800           31      3,799           266
# 37   3,800           31      3,799           266
# 38   3,800           30      3,677           257
# 39   3,800           31      3,738           262
# ...

# %%
new[new["SR #"] > 39].index
# Out:
# Int64Index([37, 38, 39, 40, 41], dtype='int64')

# %%
new.dtypes
# Out:
# SBU              object
# DEPARTMENT       object
# SUB DEPT.        object
# SR #              int64
# EMP ID            int64
# EMPLOYEE NAME    object
# EMP TYPE         object
#  SALARY          object
#  DAY WORK         int64
#  EARND AMT       object
#  S.SEC AMT        int64
# dtype: object

# %%
new
# Out:
#        SBU DEPARTMENT SUB DEPT.  SR #     EMP ID     EMPLOYEE NAME   EMP TYPE  \
# 35  C.M.T.  CLASSIC 1  CHECKING    38  200500671    MAJID ALI RAMA  Permanent
# 36  C.M.T.  CLASSIC 1  CHECKING    39  200500672      SAJJAD AHMAD  Permanent
# 37  C.M.T.  CLASSIC 1  CHECKING    40  200501073   SAIF ULLAH KHAN  Permanent
# 38  C.M.T.  CLASSIC 1  CHECKING    41  200501100  MUHAMMAD HUSSAIN  Permanent
# 39  C.M.T.  CLASSIC 1  CHECKING    42  200501106   MULAZIM HUSSAIN  Permanent
# 40  C.M.T.  CLASSIC 1  CHECKING    43  200501146          ALI ABID  Permanent
# 41  C.M.T.  CLASSIC 1  CHECKING    44  200501302     AHMAD HUSSAIN  Permanent
#
#     SALARY    DAY WORK   EARND AMT    S.SEC AMT
# 35   3,800           31      3,799           266
# 36   3,800           31      3,799           266
# 37   3,800           31      3,799           266
# 38   3,800           30      3,677           257
# 39   3,800           31      3,738           262
# ...

# %%
new.dtypes
# Out:
# SBU              object
# DEPARTMENT       object
# SUB DEPT.        object
# SR #              int64
# EMP ID            int64
# EMPLOYEE NAME    object
# EMP TYPE         object
#  SALARY          object
#  DAY WORK         int64
#  EARND AMT       object
#  S.SEC AMT        int64
# dtype: object

# %%
new.plot()

# %%
history.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017CBBD9FAC8>,
# ...
#       dtype=object)

# %%
history.plot()

# %% [markdown]
# Data Manipulating in Pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("Social.csv")

# %%
data
# Out:
#          SBU  DEPARTMENT      SUB DEPT.  SR #     EMP ID     EMPLOYEE NAME  \
# 0     C.M.T.    ACCOUNTS  GENERAL STAFF     1  111010005    MOHAMMAD ZAHID
# 1     C.M.T.    ACCOUNTS  GENERAL STAFF     2  222160527  AQEEL ANWAR KHAN
# 2     C.M.T.    ACCOUNTS  GENERAL STAFF     3  222161077    WASIF SADDIQUE
# 3     C.M.T.    ACCOUNTS  GENERAL STAFF     4  661040006        ARSHID ALI
# 4     C.M.T.       ADMIN  GENERAL STAFF     5  200501023      SAKHAWAT ALI
# ...      ...         ...            ...   ...        ...               ...
# 1724  TRENDZ  WARE HOUSE       SHIPPING  1725  200502277    MUHAMMAD SAKHI
# 1725  TRENDZ  WARE HOUSE       SHIPPING  1726  200502287   MUHAMMAD FAISAL
# 1726  TRENDZ  WARE HOUSE       SHIPPING  1727  200600079      NAVEED AHMED
# 1727     NaN         NaN            NaN   NaN        NaN               NaN
# 1728     NaN         NaN            NaN   NaN        NaN               NaN
#
#        EMP TYPE      SALARY   DAY WORK    EARND AMT   S.SEC AMT
# ...

# %%
my_data = data.tail(22)

my_data
# Out:
#          SBU    DEPARTMENT      SUB DEPT.  SR #     EMP ID  \
# 1707  TRENDZ  TRENDZ SEC 3       CHECKING  1708  200601403
# 1708  TRENDZ  TRENDZ SEC 3       CHECKING  1709  200601549
# 1709  TRENDZ  TRENDZ SEC 3  GENERAL STAFF  1710  200500044
# 1710  TRENDZ  TRENDZ SEC 3  GENERAL STAFF  1711  200500096
# 1711  TRENDZ  TRENDZ SEC 3  GENERAL STAFF  1712  200600745
# 1712  TRENDZ  TRENDZ SEC 3  GENERAL STAFF  1713  200601052
# 1713  TRENDZ  TRENDZ SEC 3  GENERAL STAFF  1714  200601288
# 1714  TRENDZ    WARE HOUSE       CHECKING  1715  200500091
# 1715  TRENDZ    WARE HOUSE  GENERAL STAFF  1716  200500230
# 1716  TRENDZ    WARE HOUSE  GENERAL STAFF  1717  222160833
# 1717  TRENDZ    WARE HOUSE       SHIPPING  1718  200400168
# 1718  TRENDZ    WARE HOUSE       SHIPPING  1719  200400181
# 1719  TRENDZ    WARE HOUSE       SHIPPING  1720  200400343
# 1720  TRENDZ    WARE HOUSE       SHIPPING  1721  200400364
# 1721  TRENDZ    WARE HOUSE       SHIPPING  1722  200501003
# ...

# %%
my_data['DEPARTMENT'].str.lower()
# Out:
# 1707    trendz sec 3
# 1708    trendz sec 3
# 1709    trendz sec 3
# 1710    trendz sec 3
# 1711    trendz sec 3
# 1712    trendz sec 3
# 1713    trendz sec 3
# 1714      ware house
# 1715      ware house
# 1716      ware house
# 1717      ware house
# 1718      ware house
# 1719      ware house
# 1720      ware house
# 1721      ware house
# 1722      ware house
# 1723      ware house
# 1724      ware house
# 1725      ware house
# 1726      ware house
# 1727             NaN
# 1728             NaN
# Name: DEPARTMENT, dtype: object

# %%
my_data["DEPARTMENT"] = my_data["DEPARTMENT"].str.lower()
# Out:
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
my_data
# Out:
#          SBU    DEPARTMENT      SUB DEPT.  SR #     EMP ID  \
# 1707  TRENDZ  trendz sec 3       CHECKING  1708  200601403
# 1708  TRENDZ  trendz sec 3       CHECKING  1709  200601549
# 1709  TRENDZ  trendz sec 3  GENERAL STAFF  1710  200500044
# 1710  TRENDZ  trendz sec 3  GENERAL STAFF  1711  200500096
# 1711  TRENDZ  trendz sec 3  GENERAL STAFF  1712  200600745
# 1712  TRENDZ  trendz sec 3  GENERAL STAFF  1713  200601052
# 1713  TRENDZ  trendz sec 3  GENERAL STAFF  1714  200601288
# 1714  TRENDZ    ware house       CHECKING  1715  200500091
# 1715  TRENDZ    ware house  GENERAL STAFF  1716  200500230
# 1716  TRENDZ    ware house  GENERAL STAFF  1717  222160833
# 1717  TRENDZ    ware house       SHIPPING  1718  200400168
# 1718  TRENDZ    ware house       SHIPPING  1719  200400181
# 1719  TRENDZ    ware house       SHIPPING  1720  200400343
# 1720  TRENDZ    ware house       SHIPPING  1721  200400364
# 1721  TRENDZ    ware house       SHIPPING  1722  200501003
# ...

# %%
my_data.fill("nann")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-44e9727ff0e6> in <module>
# ----> 1 my_data.fill("nann")
#
# E:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'fill'

# %%
data.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-118f55e0b3d0> in <module>
# ----> 1 data.plot()
#
# E:\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# E:\anaconda\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# E:\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# ...

# %%
my_data.scatter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-712e53f137a5> in <module>
# ----> 1 my_data.scatter()
#
# E:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'

# %%
my_data.hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-9aeda9977332> in <module>
# ----> 1 my_data.hist()
#
# E:\anaconda\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, **kwargs)
#     206         layout=layout,
#     207         bins=bins,
# --> 208         **kwargs,
#     209     )
#     210
#
# E:\anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     387
#     388     if naxes == 0:
# --> 389         raise ValueError("hist method requires numerical columns, nothing to plot.")
#     390
#     391     fig, axes = _subplots(
#
# ValueError: hist method requires numerical columns, nothing to plot.

# %%
my_data.dtypes
# Out:
# SBU              object
# DEPARTMENT       object
# SUB DEPT.        object
# SR #             object
# EMP ID           object
# EMPLOYEE NAME    object
# EMP TYPE         object
#  SALARY          object
#  DAY WORK        object
#  EARND AMT       object
#  S.SEC AMT       object
# dtype: object

# %%
my_data['SALARY'] = my_data["SALARY"].astype('int')

my_data.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SALARY'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-76d57c908f5b> in <module>
# ...

# %%
i for i in range(3)
# Out:
#   File "<ipython-input-21-b1b2e646dde4>", line 1
#     i  for i in range(3)
#          ^
# SyntaxError: invalid syntax

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1

# %%
for i in range(4):
    i

# %%
i
# Out:
# 3

# %%
i
# Out:
# 3

# %%
list1 = []

user = int(input("Enter any number: "))

while user > 3:
    list1.append(user)
print(list1)
# Out:
# Enter any number: 6

# %%
def new_sequence(sequences, dimenstion=10000):
    output = np.zeros((len(sequences), dimension))
    
    for i, sequence in enumerate(sequences):
        
        output[i, sequence] = 1
    return(output)

# %%
new_sequence(np.random.random(3, 4
                             ))

# %%
print("I am back after three days")
# Out:
# I am back after three days

# %%
"Fuck off"
# Out:
# 'Fuck off'

# %%
import pandas as pd

# %%
social = pd.read_csv('Social.csv')

# %%
social
# Out:
#          SBU  DEPARTMENT      SUB DEPT.  SR #     EMP ID     EMPLOYEE NAME  \
# 0     C.M.T.    ACCOUNTS  GENERAL STAFF     1  111010005    MOHAMMAD ZAHID
# 1     C.M.T.    ACCOUNTS  GENERAL STAFF     2  222160527  AQEEL ANWAR KHAN
# 2     C.M.T.    ACCOUNTS  GENERAL STAFF     3  222161077    WASIF SADDIQUE
# 3     C.M.T.    ACCOUNTS  GENERAL STAFF     4  661040006        ARSHID ALI
# 4     C.M.T.       ADMIN  GENERAL STAFF     5  200501023      SAKHAWAT ALI
# ...      ...         ...            ...   ...        ...               ...
# 1724  TRENDZ  WARE HOUSE       SHIPPING  1725  200502277    MUHAMMAD SAKHI
# 1725  TRENDZ  WARE HOUSE       SHIPPING  1726  200502287   MUHAMMAD FAISAL
# 1726  TRENDZ  WARE HOUSE       SHIPPING  1727  200600079      NAVEED AHMED
# 1727     NaN         NaN            NaN   NaN        NaN               NaN
# 1728     NaN         NaN            NaN   NaN        NaN               NaN
#
#        EMP TYPE      SALARY   DAY WORK    EARND AMT   S.SEC AMT
# ...

# %%
Emp_Data = social.tail(15)

# %%
Emp_Data
# Out:
#          SBU  DEPARTMENT      SUB DEPT.  SR #     EMP ID        EMPLOYEE NAME  \
# 1714  TRENDZ  WARE HOUSE       CHECKING  1715  200500091      SYED AWON ABBAS
# 1715  TRENDZ  WARE HOUSE  GENERAL STAFF  1716  200500230           NADIR KHAN
# 1716  TRENDZ  WARE HOUSE  GENERAL STAFF  1717  222160833           FIAZ AHMED
# 1717  TRENDZ  WARE HOUSE       SHIPPING  1718  200400168     M. TAHIR MEHMOOD
# 1718  TRENDZ  WARE HOUSE       SHIPPING  1719  200400181        ASHIQ HUSSAIN
# 1719  TRENDZ  WARE HOUSE       SHIPPING  1720  200400343            ALI JAFAR
# 1720  TRENDZ  WARE HOUSE       SHIPPING  1721  200400364  MUHAMMAD TAHIR KHAN
# 1721  TRENDZ  WARE HOUSE       SHIPPING  1722  200501003      MUHAMMAD SHAHID
# 1722  TRENDZ  WARE HOUSE       SHIPPING  1723  200501823      MUHAMMAD YOUNAS
# 1723  TRENDZ  WARE HOUSE       SHIPPING  1724  200502147        MUHAMMAD IJAZ
# 1724  TRENDZ  WARE HOUSE       SHIPPING  1725  200502277       MUHAMMAD SAKHI
# ...

# %%
pd.DataFrame({'Car': 1344, 'cycle': 3322})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-9c665500b9db> in <module>
# ----> 1 pd.DataFrame({'Car': 1344, 'cycle': 3322})
#
# E:\anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# E:\anaconda\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %%
Emp_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 1714 to 1728
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SBU            13 non-null     object
#  1   DEPARTMENT     13 non-null     object
#  2   SUB DEPT.      13 non-null     object
#  3   SR #           13 non-null     object
#  4   EMP ID         13 non-null     object
#  5   EMPLOYEE NAME  13 non-null     object
#  6   EMP TYPE       13 non-null     object
#  7    SALARY        14 non-null     object
#  8    DAY WORK      14 non-null     object
#  9    EARND AMT     14 non-null     object
#  10   S.SEC AMT     14 non-null     object
# dtypes: object(11)
# memory usage: 1.4+ KB

# %%
Emp_Data.describe()
# Out:
#            SBU  DEPARTMENT SUB DEPT.  SR #     EMP ID    EMPLOYEE NAME  \
# count       13          13        13    13         13               13
# unique       1           1         3    13         13               13
# top     TRENDZ  WARE HOUSE  SHIPPING  1724  200500091  MUHAMMAD SHAHID
# freq        13          13        10     1          1                1
#
#          EMP TYPE  SALARY   DAY WORK   EARND AMT   S.SEC AMT
# count          13       14         14          14          14
# unique          1        8          5          11          11
# top     Permanent   4,000         31       3,999         280
# freq           13        5          9           4           4

# %%
Emp_Data.columns
# Out:
# Index(['SBU', 'DEPARTMENT', 'SUB DEPT.', 'SR #', 'EMP ID', 'EMPLOYEE NAME',
#        'EMP TYPE', ' SALARY ', ' DAY WORK ', ' EARND AMT ', ' S.SEC AMT '],
#       dtype='object')

# %%
Emp_Data.dtypes
# Out:
# SBU              object
# DEPARTMENT       object
# SUB DEPT.        object
# SR #             object
# EMP ID           object
# EMPLOYEE NAME    object
# EMP TYPE         object
#  SALARY          object
#  DAY WORK        object
#  EARND AMT       object
#  S.SEC AMT       object
# dtype: object

# %%
Emp_Data.to_csv("Emp_Data.csv")

# %%
Emp_Data
# Out:
#          SBU  DEPARTMENT      SUB DEPT.  SR #     EMP ID        EMPLOYEE NAME  \
# 1714  TRENDZ  WARE HOUSE       CHECKING  1715  200500091      SYED AWON ABBAS
# 1715  TRENDZ  WARE HOUSE  GENERAL STAFF  1716  200500230           NADIR KHAN
# 1716  TRENDZ  WARE HOUSE  GENERAL STAFF  1717  222160833           FIAZ AHMED
# 1717  TRENDZ  WARE HOUSE       SHIPPING  1718  200400168     M. TAHIR MEHMOOD
# 1718  TRENDZ  WARE HOUSE       SHIPPING  1719  200400181        ASHIQ HUSSAIN
# 1719  TRENDZ  WARE HOUSE       SHIPPING  1720  200400343            ALI JAFAR
# 1720  TRENDZ  WARE HOUSE       SHIPPING  1721  200400364  MUHAMMAD TAHIR KHAN
# 1721  TRENDZ  WARE HOUSE       SHIPPING  1722  200501003      MUHAMMAD SHAHID
# 1722  TRENDZ  WARE HOUSE       SHIPPING  1723  200501823      MUHAMMAD YOUNAS
# 1723  TRENDZ  WARE HOUSE       SHIPPING  1724  200502147        MUHAMMAD IJAZ
# 1724  TRENDZ  WARE HOUSE       SHIPPING  1725  200502277       MUHAMMAD SAKHI
# ...

# %%
import pandas as pd

# %%
Emp_History = pd.read_csv('history.csv')

Emp_History
# Out:
#        SBU      DEPARTMENT      SUB DEPT.  SR #     EMP ID  \
# 0   C.M.T.        ACCOUNTS  GENERAL STAFF     3  222161077
# 1   C.M.T.        ACCOUNTS  GENERAL STAFF     4  661040006
# 2   C.M.T.           ADMIN  GENERAL STAFF     5  200501023
# 3   C.M.T.           ADMIN  GENERAL STAFF     6  222160242
# 4   C.M.T.           ADMIN  GENERAL STAFF     7  222160309
# 5   C.M.T.           ADMIN  GENERAL STAFF     8  222161128
# 6   C.M.T.           ADMIN  GENERAL STAFF     9  222161197
# 7   C.M.T.           ADMIN        SWEEPER    10  111070041
# 8   C.M.T.           ADMIN        SWEEPER    11  222161107
# 9   C.M.T.  C.M.T. CUTTING       CHECKING    12  200502098
# 10  C.M.T.  C.M.T. CUTTING       CHECKING    13  200600069
# 11  C.M.T.  C.M.T. CUTTING       CHECKING    14  200600333
# 12  C.M.T.  C.M.T. CUTTING       CHECKING    15  200600399
# 13  C.M.T.  C.M.T. CUTTING       CHECKING    16  200600662
# 14  C.M.T.  C.M.T. CUTTING       CHECKING    17  200600704
# ...

# %% [raw]
# Manipulating Data

# %%
Sorted = Emp_History.head()

# %%
Sorted
# Out:
#       SBU DEPARTMENT      SUB DEPT.  SR #     EMP ID   EMPLOYEE NAME  \
# 0  C.M.T.   ACCOUNTS  GENERAL STAFF     3  222161077  WASIF SADDIQUE
# 1  C.M.T.   ACCOUNTS  GENERAL STAFF     4  661040006      ARSHID ALI
# 2  C.M.T.      ADMIN  GENERAL STAFF     5  200501023    SAKHAWAT ALI
# 3  C.M.T.      ADMIN  GENERAL STAFF     6  222160242   KHALID MASIH.
# 4  C.M.T.      ADMIN  GENERAL STAFF     7  222160309     AKHTAR ALI.
#
#     EMP TYPE  SALARY    DAY WORK   EARND AMT    S.SEC AMT
# 0  Permanent   4,600           31      4,600           322
# 1  Permanent   7,500           31      7,500           350
# 2  Permanent   4,200           30      4,064           284
# 3  Permanent   4,716           31      4,715           330
# 4  Permanent   7,361           31      7,361           350

# %%
Emp_Data = pd.read_csv('Emp_Data.csv')

# %%
Emp_Data
# Out:
#     Unnamed: 0     SBU  DEPARTMENT      SUB DEPT.    SR #       EMP ID  \
# 0         1714  TRENDZ  WARE HOUSE       CHECKING  1715.0  200500091.0
# 1         1715  TRENDZ  WARE HOUSE  GENERAL STAFF  1716.0  200500230.0
# 2         1716  TRENDZ  WARE HOUSE  GENERAL STAFF  1717.0  222160833.0
# 3         1717  TRENDZ  WARE HOUSE       SHIPPING  1718.0  200400168.0
# 4         1718  TRENDZ  WARE HOUSE       SHIPPING  1719.0  200400181.0
# 5         1719  TRENDZ  WARE HOUSE       SHIPPING  1720.0  200400343.0
# 6         1720  TRENDZ  WARE HOUSE       SHIPPING  1721.0  200400364.0
# 7         1721  TRENDZ  WARE HOUSE       SHIPPING  1722.0  200501003.0
# 8         1722  TRENDZ  WARE HOUSE       SHIPPING  1723.0  200501823.0
# 9         1723  TRENDZ  WARE HOUSE       SHIPPING  1724.0  200502147.0
# 10        1724  TRENDZ  WARE HOUSE       SHIPPING  1725.0  200502277.0
# 11        1725  TRENDZ  WARE HOUSE       SHIPPING  1726.0  200502287.0
# ...

# %%
Emp_Data.fillna('Fahad')
# Out:
#     Unnamed: 0     SBU  DEPARTMENT      SUB DEPT.   SR #       EMP ID  \
# 0         1714  TRENDZ  WARE HOUSE       CHECKING   1715    2.005e+08
# 1         1715  TRENDZ  WARE HOUSE  GENERAL STAFF   1716    2.005e+08
# 2         1716  TRENDZ  WARE HOUSE  GENERAL STAFF   1717  2.22161e+08
# 3         1717  TRENDZ  WARE HOUSE       SHIPPING   1718    2.004e+08
# 4         1718  TRENDZ  WARE HOUSE       SHIPPING   1719    2.004e+08
# 5         1719  TRENDZ  WARE HOUSE       SHIPPING   1720    2.004e+08
# 6         1720  TRENDZ  WARE HOUSE       SHIPPING   1721    2.004e+08
# 7         1721  TRENDZ  WARE HOUSE       SHIPPING   1722  2.00501e+08
# 8         1722  TRENDZ  WARE HOUSE       SHIPPING   1723  2.00502e+08
# 9         1723  TRENDZ  WARE HOUSE       SHIPPING   1724  2.00502e+08
# 10        1724  TRENDZ  WARE HOUSE       SHIPPING   1725  2.00502e+08
# 11        1725  TRENDZ  WARE HOUSE       SHIPPING   1726  2.00502e+08
# ...

# %%
Emp_Data["EMP TYPE"] = Emp_Data["EMP TYPE"].fillna('Fahad_43')

Emp_Data['EMP TYPE']
# Out:
# 0     Permanent
# 1     Permanent
# 2     Permanent
# 3     Permanent
# 4     Permanent
# 5     Permanent
# 6     Permanent
# 7     Permanent
# 8     Permanent
# 9     Permanent
# 10    Permanent
# 11    Permanent
# 12    Permanent
# 13     Fahad_43
# 14     Fahad_43
# Name: EMP TYPE, dtype: object

# %%
Emp_Data
# Out:
#     Unnamed: 0     SBU  DEPARTMENT      SUB DEPT.    SR #       EMP ID  \
# 0         1714  TRENDZ  WARE HOUSE       CHECKING  1715.0  200500091.0
# 1         1715  TRENDZ  WARE HOUSE  GENERAL STAFF  1716.0  200500230.0
# 2         1716  TRENDZ  WARE HOUSE  GENERAL STAFF  1717.0  222160833.0
# 3         1717  TRENDZ  WARE HOUSE       SHIPPING  1718.0  200400168.0
# 4         1718  TRENDZ  WARE HOUSE       SHIPPING  1719.0  200400181.0
# 5         1719  TRENDZ  WARE HOUSE       SHIPPING  1720.0  200400343.0
# 6         1720  TRENDZ  WARE HOUSE       SHIPPING  1721.0  200400364.0
# 7         1721  TRENDZ  WARE HOUSE       SHIPPING  1722.0  200501003.0
# 8         1722  TRENDZ  WARE HOUSE       SHIPPING  1723.0  200501823.0
# 9         1723  TRENDZ  WARE HOUSE       SHIPPING  1724.0  200502147.0
# 10        1724  TRENDZ  WARE HOUSE       SHIPPING  1725.0  200502277.0
# 11        1725  TRENDZ  WARE HOUSE       SHIPPING  1726.0  200502287.0
# ...

# %%
Emp_Data["SR #"].fillna(Emp_Data["SR #"].mean(), inplace= True)

# %%
Emp_Data["SR #"].mean()
# Out:
# 1721.0

# %%
Emp_Data
# Out:
#     Unnamed: 0     SBU  DEPARTMENT      SUB DEPT.    SR #       EMP ID  \
# 0         1714  TRENDZ  WARE HOUSE       CHECKING  1715.0  200500091.0
# 1         1715  TRENDZ  WARE HOUSE  GENERAL STAFF  1716.0  200500230.0
# 2         1716  TRENDZ  WARE HOUSE  GENERAL STAFF  1717.0  222160833.0
# 3         1717  TRENDZ  WARE HOUSE       SHIPPING  1718.0  200400168.0
# 4         1718  TRENDZ  WARE HOUSE       SHIPPING  1719.0  200400181.0
# 5         1719  TRENDZ  WARE HOUSE       SHIPPING  1720.0  200400343.0
# 6         1720  TRENDZ  WARE HOUSE       SHIPPING  1721.0  200400364.0
# 7         1721  TRENDZ  WARE HOUSE       SHIPPING  1722.0  200501003.0
# 8         1722  TRENDZ  WARE HOUSE       SHIPPING  1723.0  200501823.0
# 9         1723  TRENDZ  WARE HOUSE       SHIPPING  1724.0  200502147.0
# 10        1724  TRENDZ  WARE HOUSE       SHIPPING  1725.0  200502277.0
# 11        1725  TRENDZ  WARE HOUSE       SHIPPING  1726.0  200502287.0
# ...

# %%
Emp_Data.dropna()
# Out:
#     Unnamed: 0     SBU  DEPARTMENT      SUB DEPT.    SR #       EMP ID  \
# 0         1714  TRENDZ  WARE HOUSE       CHECKING  1715.0  200500091.0
# 1         1715  TRENDZ  WARE HOUSE  GENERAL STAFF  1716.0  200500230.0
# 2         1716  TRENDZ  WARE HOUSE  GENERAL STAFF  1717.0  222160833.0
# 3         1717  TRENDZ  WARE HOUSE       SHIPPING  1718.0  200400168.0
# 4         1718  TRENDZ  WARE HOUSE       SHIPPING  1719.0  200400181.0
# 5         1719  TRENDZ  WARE HOUSE       SHIPPING  1720.0  200400343.0
# 6         1720  TRENDZ  WARE HOUSE       SHIPPING  1721.0  200400364.0
# 7         1721  TRENDZ  WARE HOUSE       SHIPPING  1722.0  200501003.0
# 8         1722  TRENDZ  WARE HOUSE       SHIPPING  1723.0  200501823.0
# 9         1723  TRENDZ  WARE HOUSE       SHIPPING  1724.0  200502147.0
# 10        1724  TRENDZ  WARE HOUSE       SHIPPING  1725.0  200502277.0
# 11        1725  TRENDZ  WARE HOUSE       SHIPPING  1726.0  200502287.0
# ...
